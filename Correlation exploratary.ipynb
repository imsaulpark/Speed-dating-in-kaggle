# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

df_data = pd.read_csv("data/Speed Dating Data.csv")
df_data.shape
# Out:
# (8378, 195)

# %%
col = ["date", "go_out", "exphappy", "expnum", "dec"]

data = df_data.loc[:, col]
data = data.dropna(axis=0)
data

plt.figure(figsize=(15, 15))
sns.heatmap(data = data.corr(), annot = True)

# %%
col = ['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1', "dec"]
col = ['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1', "dec"]
data = df_data.loc[:, col]

plt.figure(figsize=(15, 15))
sns.heatmap(data = data.corr(), annot = True)

# %%
df_data.columns.values

col = ['dec', 'met', 'attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob']

data = df_data.loc[:, col]

print(data.shape)
msno.matrix( data )

data = data.dropna(axis=0)
print(data.shape)

print(data.head())

plt.figure(figsize=(15, 15))
sns.heatmap(data = data.corr(), annot = True)
# Out:
# (8378, 10)
# (6819, 10)
#    dec  met  attr  sinc  intel  fun  amb  shar  like  prob
# 0    1  2.0   6.0   9.0    7.0  7.0  6.0   5.0   7.0   6.0
# 1    1  1.0   7.0   8.0    7.0  8.0  5.0   6.0   7.0   5.0
# 3    1  2.0   7.0   6.0    8.0  7.0  6.0   8.0   7.0   6.0
# 4    1  2.0   5.0   6.0    7.0  7.0  6.0   6.0   6.0   6.0
# 5    0  2.0   4.0   9.0    7.0  4.0  6.0   4.0   6.0   5.0

# %%
df_data.columns.values
# Out:
# array(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round',
#        'position', 'positin1', 'order', 'partner', 'pid', 'match',
#        'int_corr', 'samerace', 'age_o', 'race_o', 'pf_o_att', 'pf_o_sin',
#        'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha', 'dec_o', 'attr_o',
#        'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o',
#        'prob_o', 'met_o', 'age', 'field', 'field_cd', 'undergra',
#        'mn_sat', 'tuition', 'race', 'imprace', 'imprelig', 'from',
#        'zipcode', 'income', 'goal', 'date', 'go_out', 'career',
#        'career_c', 'sports', 'tvsports', 'exercise', 'dining', 'museums',
#        'art', 'hiking', 'gaming', 'clubbing', 'reading', 'tv', 'theater',
#        'movies', 'concerts', 'music', 'shopping', 'yoga', 'exphappy',
#        'expnum', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1',
#        'shar1_1', 'attr4_1', 'sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1',
# ...

# %%
col = ['samerace', 'dec']
data = df_data.loc[: , col]

plt.figure(figsize=(15, 15))
# sns.barplot(x = data['samerace'], y = data['dec'])
sns.heatmap(data = data.corr(), annot = True)
