# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_data = pd.read_csv("data/Speed Dating Data.csv")
df_data.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#     ...    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  \
# 0   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 1   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 2   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 3   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
# 4   ...        5.0      7.0       7.0     7.0     7.0      NaN      NaN
#
#    intel5_3  fun5_3  amb5_3
# 0       NaN     NaN     NaN
# 1       NaN     NaN     NaN
# ...

# %%
import missingno as msno

df_missing = merged_df.columns[df_data.isnull().any()].tolist()
msno.matrix(df_missing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a0eb093e9d03> in <module>()
#       1 import missingno as msno
#       2
# ----> 3 df_missing = merged_df.columns[df_data.isnull().any()].tolist()
#       4 msno.matrix(df_missing)
#
# NameError: name 'merged_df' is not defined
