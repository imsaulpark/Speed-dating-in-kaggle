# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno

df_data = pd.read_csv("data/Speed Dating Data.csv")
df_data.shape
# Out:
# (8378, 195)

# %% [markdown]
# # Set Dataframe by 'iid'
# we define this dataframe as 'df_droppped'.
# and we'll use this dataframe for making following dataframe about each personal property.
# - profile
# - time1, halfway, time2, time3

# %%
df_dropped = df_data.drop_duplicates(["iid"])
df_dropped.set_index('iid', inplace=True)
df_dropped.head()
# Out:
#       id  gender  idg  condtn  wave  round  position  positin1  order  \
# iid
# 1    1.0       0    1       1     1     10         7       NaN      4
# 2    2.0       0    3       1     1     10         3       NaN     10
# 3    3.0       0    5       1     1     10         9       NaN      6
# 4    4.0       0    7       1     1     10         6       NaN      3
# 5    5.0       0    9       1     1     10         4       NaN      1
#
#      partner   ...    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  \
# iid            ...
# 1          1   ...        5.0      7.0       7.0     7.0     7.0      NaN
# 2          1   ...        7.0      6.0       9.0     9.0     4.0      NaN
# 3          1   ...        NaN      NaN       NaN     NaN     NaN      NaN
# 4          1   ...        6.0      5.0       6.0     8.0     5.0      NaN
# 5          1   ...        4.0      5.0      10.0     6.0    10.0      NaN
#
#      sinc5_3  intel5_3  fun5_3  amb5_3
# iid
# ...

# %%
# print missing values rate.
print(df_dropped.isnull().sum().sum() / df_dropped.size)

msno.matrix( df_dropped )
# Out:
# 0.2679102662450652

# %% [markdown]
# # 1. Profile

# %%
df_profile = df_dropped.loc[ :, "age" : "expnum"]
df_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 551 entries, 1 to 552
# Data columns (total 36 columns):
# age         543 non-null float64
# field       545 non-null object
# field_cd    544 non-null float64
# undergra    315 non-null object
# mn_sat      202 non-null object
# tuition     234 non-null object
# race        545 non-null float64
# imprace     544 non-null float64
# imprelig    544 non-null float64
# from        544 non-null object
# zipcode     475 non-null object
# income      281 non-null object
# goal        544 non-null float64
# date        543 non-null float64
# go_out      544 non-null float64
# career      543 non-null object
# career_c    539 non-null float64
# sports      544 non-null float64
# tvsports    544 non-null float64
# exercise    544 non-null float64
# dining      544 non-null float64
# museums     544 non-null float64
# art         544 non-null float64
# hiking      544 non-null float64
# gaming      544 non-null float64
# ...

# %%
print( df_profile.shape )
# print missing values rate.
print( df_profile.isnull().sum().sum() / df_profile.size) 

msno.matrix( df_profile )
# Out:
# (551, 36)
# 0.09528130671506352

# %% [markdown]
# # 2. Attribute.

# %% [markdown]
# ### Time 1

# %%
col_attrX_1 = ['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1',
            'attr2_1', 'sinc2_1', 'intel2_1', 'fun2_1', 'amb2_1', 'shar2_1',
            'attr3_1', 'sinc3_1', 'fun3_1', 'intel3_1', 'amb3_1',
            'attr4_1', 'sinc4_1', 'intel4_1', 'fun4_1', 'amb4_1', 'shar4_1',
            'attr5_1', 'sinc5_1', 'intel5_1', 'fun5_1', 'amb5_1'
           ]
df_attrX_1 = df_dropped.loc[:, col_attrX_1]

print( df_attrX_1.shape )
# print missing values rate.
print( df_attrX_1.isnull().sum().sum() / df_attrX_1.size) 

msno.matrix( df_attrX_1 )
# Out:
# (551, 28)
# 0.1378662172673062

# %% [markdown]
# ### Time Half way

# %%
col_attrX_s = ['attr1_s', 'sinc1_s', 'intel1_s', 'fun1_s', 'amb1_s', 'shar1_s',
               'attr3_s', 'sinc3_s', 'intel3_s', 'fun3_s', 'amb3_s',
              ]
df_attrX_s = df_dropped.loc[:, col_attrX_s]

print( df_attrX_s.shape )
# print missing values rate.
print( df_attrX_s.isnull().sum().sum() / df_attrX_s.size) 

msno.matrix( df_attrX_s )
# Out:
# (551, 11)
# 0.4941428807127537

# %% [markdown]
# ### Time 2

# %%
col_attrX_2 = ['satis_2', 'length', 'numdat_2',
               'attr7_2', 'sinc7_2', 'intel7_2', 'fun7_2', 'amb7_2', 'shar7_2',
               'attr1_2', 'sinc1_2', 'intel1_2', 'fun1_2', 'amb1_2', 'shar1_2',
               'attr4_2', 'sinc4_2', 'intel4_2', 'fun4_2', 'amb4_2', 'shar4_2',
               'attr2_2', 'sinc2_2', 'intel2_2', 'fun2_2', 'amb2_2', 'shar2_2',
               'attr3_2', 'sinc3_2', 'intel3_2', 'fun3_2', 'amb3_2',
               'attr5_2', 'sinc5_2', 'intel5_2', 'fun5_2', 'amb5_2']
df_attrX_2 = df_dropped.loc[:, col_attrX_2]

print( df_attrX_2.shape )
# print missing values rate.
print( df_attrX_2.isnull().sum().sum() / df_attrX_2.size) 

msno.matrix( df_attrX_2 )
# Out:
# (551, 37)
# 0.34575955265610436

# %% [markdown]
# ### Time 3

# %%
col_attrX_3 = ['you_call', 'them_cal', 'date_3', 'numdat_3', 'num_in_3',
               'attr1_3', 'sinc1_3', 'intel1_3', 'fun1_3', 'amb1_3', 'shar1_3',
               'attr7_3', 'sinc7_3', 'intel7_3', 'fun7_3', 'amb7_3', 'shar7_3',
               'attr4_3', 'sinc4_3', 'intel4_3', 'fun4_3', 'amb4_3', 'shar4_3',
               'attr2_3', 'sinc2_3', 'intel2_3', 'fun2_3', 'amb2_3', 'shar2_3',
               'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3',
               'attr5_3', 'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3']
df_attrX_3 = df_dropped.loc[:, col_attrX_3]

print( df_attrX_3.shape )
# print missing values rate.
print( df_attrX_3.isnull().sum().sum() / df_attrX_3.size) 

msno.matrix( df_attrX_3 )
# Out:
# (551, 39)
# 0.6505188701195961

# %% [markdown]
# # 3. Score Card

# %%
col_score = ['gender', 'wave', 'partner', 'pid', 'match', 'int_corr',
        'samerace', 'age_o', 'race_o',
        'pf_o_att', 'pf_o_sin', 'pf_o_int', 'pf_o_fun', 'pf_o_amb', 'pf_o_sha',
        'dec_o', 'attr_o', 'sinc_o', 'intel_o', 'fun_o', 'amb_o', 'shar_o', 'like_o', 'prob_o', 'met_o',
        'dec', 'attr', 'sinc', 'intel','fun', 'amb', 'shar', 'like', 'prob', 'met', 'match_es']

df_score = df_data.loc[:, col_score]

print( df_score.shape )
# print missing values rate.
print( df_score.isnull().sum().sum() / df_score.size) 

msno.matrix( df_score )
# Out:
# (8378, 36)
# 0.03270138723110793
